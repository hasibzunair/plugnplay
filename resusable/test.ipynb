# %%
# %load_ext autoreload
# %autoreload 2

# %%
from resize import read_resize_image
from rembck import remove_background
from sklearn.datasets import load_sample_image
from sklearn.feature_extraction import image
import matplotlib.pyplot as plt
import numpy as np
import PIL
from PIL import Image
# Out:
# OMP: Info #271: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
# one_image = load_sample_image("china.jpg")
# print('Image shape: {}'.format(one_image.shape))
# plt.imshow(one_image)

# %%
# Convert from np.array to PIL
# PIL_image = Image.fromarray(np.uint8(one_image)).convert('RGB')

# %%
# PIL_image

# %% [markdown]
# ### Resize image

# %%
# resize image
path = "images/person.jpg"

image = read_resize_image(path, 224, 224)
print(image.shape)
plt.imshow(image)
# Out:
# (224, 224, 3)

# %% [markdown]
# ### Remove background

# %%
i = Image.open(path)
a = remove_background(i)

# %%
a
# Out:
# <PIL.Image.Image image mode=RGBA size=192x256 at 0x7FDAC645EC40>

# %%
a.save("images/person_bg.png")
